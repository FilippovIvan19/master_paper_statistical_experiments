# %%
import os
os.chdir('../..')

# %%
import numpy as np
from nilmtk import STATS_CACHE

from utils.constants import DatasetType, DAY_IN_SEC
from utils.data_reading import clean_and_store_data, read_cleaned_data, \
    convert_to_nilmtk_format, store_processed_stable_periods, \
    get_full_keys_of_stable_periods, read_stable_periods, process_stable_periods
from utils.preprocessing import generate_sync_signals, get_stable_periods, \
    interpolate_missed_data, generate_async_signals, reformat_to_accumulated
from utils.timing import time_measure
from utils.visualization import plot_sync_async_comparison

STATS_CACHE.store.close()


DS = DatasetType.IDEAL
DURATION = DAY_IN_SEC*30
MAX_GAP = 300

# %%
process_stable_periods(DS, DURATION, MAX_GAP)
# Out:
# [getting stable periods] finished in 0m 39.55s
# [storing stable periods of IDEAL/building_105 with duration = 2592000s and max_gap = 300s] finished in 0m 5.63s
# [getting stable periods] finished in 0m 45.14s
# [storing stable periods of IDEAL/building_106 with duration = 2592000s and max_gap = 300s] finished in 0m 4.03s
# [getting stable periods] finished in 0m 35.78s
# [storing stable periods of IDEAL/building_128 with duration = 2592000s and max_gap = 300s] finished in 0m 1.84s
# [getting stable periods] finished in 0m 40.45s
# [storing stable periods of IDEAL/building_136 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 25.72s
# [storing stable periods of IDEAL/building_139 with duration = 2592000s and max_gap = 300s] finished in 0m 1.75s
# [getting stable periods] finished in 0m 21.27s
# [storing stable periods of IDEAL/building_140 with duration = 2592000s and max_gap = 300s] finished in 0m 1.73s
# [getting stable periods] finished in 0m 31.21s
# [storing stable periods of IDEAL/building_145 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 38.56s
# [storing stable periods of IDEAL/building_146 with duration = 2592000s and max_gap = 300s] finished in 0m 4.04s
# [getting stable periods] finished in 0m 30.34s
# [storing stable periods of IDEAL/building_162 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 29.27s
# [storing stable periods of IDEAL/building_168 with duration = 2592000s and max_gap = 300s] finished in 0m 1.91s
# [getting stable periods] finished in 0m 30.88s
# [storing stable periods of IDEAL/building_169 with duration = 2592000s and max_gap = 300s] finished in 0m 1.84s
# [getting stable periods] finished in 0m 10.37s
# [storing stable periods of IDEAL/building_171 with duration = 2592000s and max_gap = 300s] finished in 0m 0.02s
# [getting stable periods] finished in 0m 33.27s
# [storing stable periods of IDEAL/building_175 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 28.38s
# [storing stable periods of IDEAL/building_208 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 24.85s
# [storing stable periods of IDEAL/building_212 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 26.25s
# [storing stable periods of IDEAL/building_225 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 17.76s
# [storing stable periods of IDEAL/building_227 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 22.81s
# [storing stable periods of IDEAL/building_228 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 21.11s
# [storing stable periods of IDEAL/building_231 with duration = 2592000s and max_gap = 300s] finished in 0m 0.02s
# [getting stable periods] finished in 0m 24.32s
# [storing stable periods of IDEAL/building_238 with duration = 2592000s and max_gap = 300s] finished in 0m 0.02s
# [getting stable periods] finished in 0m 24.02s
# [storing stable periods of IDEAL/building_242 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 16.45s
# [storing stable periods of IDEAL/building_249 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 23.15s
# [storing stable periods of IDEAL/building_255 with duration = 2592000s and max_gap = 300s] finished in 0m 0.02s
# [getting stable periods] finished in 0m 19.79s
# [storing stable periods of IDEAL/building_259 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 21.78s
# [storing stable periods of IDEAL/building_262 with duration = 2592000s and max_gap = 300s] finished in 0m 0.02s
# [getting stable periods] finished in 0m 21.25s
# [storing stable periods of IDEAL/building_263 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 21.83s
# [storing stable periods of IDEAL/building_264 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 15.87s
# [storing stable periods of IDEAL/building_266 with duration = 2592000s and max_gap = 300s] finished in 0m 0.03s
# [getting stable periods] finished in 0m 20.51s
# [storing stable periods of IDEAL/building_268 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 14.69s
# [storing stable periods of IDEAL/building_276 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 11.46s
# [storing stable periods of IDEAL/building_311 with duration = 2592000s and max_gap = 300s] finished in 0m 0.02s
# [getting stable periods] finished in 0m 9.47s
# [storing stable periods of IDEAL/building_328 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 38.80s
# [storing stable periods of IDEAL/building_61 with duration = 2592000s and max_gap = 300s] finished in 0m 0.02s
# [getting stable periods] finished in 1m 14.71s
# [storing stable periods of IDEAL/building_62 with duration = 2592000s and max_gap = 300s] finished in 0m 7.19s
# [getting stable periods] finished in 0m 53.95s
# [storing stable periods of IDEAL/building_63 with duration = 2592000s and max_gap = 300s] finished in 0m 1.82s
# [getting stable periods] finished in 1m 4.34s
# [storing stable periods of IDEAL/building_65 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 52.52s
# [storing stable periods of IDEAL/building_73 with duration = 2592000s and max_gap = 300s] finished in 0m 1.71s
# [getting stable periods] finished in 0m 40.49s
# [storing stable periods of IDEAL/building_90 with duration = 2592000s and max_gap = 300s] finished in 0m 0.01s
# [getting stable periods] finished in 0m 40.00s
# [storing stable periods of IDEAL/building_96 with duration = 2592000s and max_gap = 300s] finished in 0m 3.68s
# [processing stable periods for IDEAL dataset] finished in 21m 31.74s

# %%
full_keys = get_full_keys_of_stable_periods(DS)
print(len(full_keys))
# Out:
# 20

# %%
accumulated = read_stable_periods(DS, [full_keys[8]])[0]

sync_signals = generate_sync_signals(accumulated, 100)
print('len(sync_signals)', len(sync_signals))

async_signals = generate_async_signals(accumulated, 21000)
print('len(async_signals)', len(async_signals))

plot_sync_async_comparison(accumulated, sync_signals, async_signals)
# Out:
# [reading 1 stable periods of IDEAL] finished in 0m 0.19s
# [generating sync signals] finished in 0m 0.00s
# len(sync_signals) 25921
# [generating async signals] finished in 0m 0.38s
# len(async_signals) 39593

# %%
1e10+1e-6
# Out:
# 10000000000.000002

# %%
import numpy as np
from nilmtk import STATS_CACHE

from utils.constants import DatasetType, DAY_IN_SEC
from utils.data_reading import clean_and_store_data, read_cleaned_data, \
    convert_to_nilmtk_format, store_processed_stable_periods, \
    get_full_keys_of_stable_periods, read_stable_periods
from utils.preprocessing import generate_sync_signals, get_stable_periods, \
    interpolate_missed_data, generate_async_signals, reformat_to_accumulated
from utils.timing import time_measure
from utils.visualization import plot_sync_async_comparison

STATS_CACHE.store.close()


DS = DatasetType.IDEAL
DURATION = DAY_IN_SEC*30
MAX_GAP = 300

# convert_to_nilmtk_format(DS)
# clean_and_store_data(DS)
# ideal = read_cleaned_data(DS)
# process_stable_periods(DS, DURATION, MAX_GAP)

full_keys = get_full_keys_of_stable_periods(DS)
accumulated = read_stable_periods(DS, [full_keys[-3]])[0]

sync_signals = generate_sync_signals(accumulated, 100)
print('len(sync_signals)', len(sync_signals))
# print(sync_signals.head())
# print(sync_signals.tail())

async_signals = generate_async_signals(accumulated, 10000.5)
print('len(async_signals)', len(async_signals))
# print(async_signals.head())
# print(async_signals.tail())

plot_sync_async_comparison(accumulated, sync_signals, async_signals)
# Out:
# [reading 1 stable periods of IDEAL] finished in 0m 0.20s
# [generating sync signals] finished in 0m 0.00s
# len(sync_signals) 25921
# [generating async signals] finished in 0m 0.38s
# len(async_signals) 50541

# %%
full_keys
# Out:
# ['/building_96/dur_2592000/gap_300/n_0',
#  '/building_96/dur_2592000/gap_300/n_1',
#  '/building_73/dur_2592000/gap_300/n_0',
#  '/building_63/dur_2592000/gap_300/n_0',
#  '/building_62/dur_2592000/gap_300/n_0',
#  '/building_62/dur_2592000/gap_300/n_1',
#  '/building_62/dur_2592000/gap_300/n_2',
#  '/building_62/dur_2592000/gap_300/n_3',
#  '/building_169/dur_2592000/gap_300/n_0',
#  '/building_168/dur_2592000/gap_300/n_0',
#  '/building_146/dur_2592000/gap_300/n_0',
#  '/building_146/dur_2592000/gap_300/n_1',
#  '/building_140/dur_2592000/gap_300/n_0',
#  '/building_139/dur_2592000/gap_300/n_0',
#  '/building_128/dur_2592000/gap_300/n_0',
#  '/building_106/dur_2592000/gap_300/n_0',
#  '/building_106/dur_2592000/gap_300/n_1',
#  '/building_105/dur_2592000/gap_300/n_0',
#  '/building_105/dur_2592000/gap_300/n_1',
#  '/building_105/dur_2592000/gap_300/n_2']
